# %%
import pandas as pd 
import numpy  as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df['BMI'] = df['BMI'].replace(0,df['BMI'].mean())
df['BloodPressure'] = df['BloodPressure'].replace(0,df['BloodPressure'].mean())
df['Glucose'] = df['Glucose'].replace(0,df['Glucose'].mean())
df['Insulin'] = df['Insulin'].replace(0,df['Insulin'].mean())
df['SkinThickness'] = df['SkinThickness'].replace(0,df['SkinThickness'].mean())

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6    148.0           72.0      35.000000   79.799479  33.6
# 1              1     85.0           66.0      29.000000   79.799479  26.6
# 2              8    183.0           64.0      20.536458   79.799479  23.3
# 3              1     89.0           66.0      23.000000   94.000000  28.1
# 4              0    137.0           40.0      35.000000  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763           10    101.0           76.0      48.000000  180.000000  32.9
# 764            2    122.0           70.0      27.000000   79.799479  36.8
# 765            5    121.0           72.0      23.000000  112.000000  26.2
# 766            1    126.0           60.0      20.536458   79.799479  30.1
# 767            1     93.0           70.0      31.000000   79.799479  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  121.681605      72.254807      26.606479  118.660163
# std       3.369578   30.436016      12.115932       9.631241   93.080358
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.750000      64.000000      20.536458   79.799479
# 50%       3.000000  117.000000      72.000000      23.000000   79.799479
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    32.450805                  0.471876   33.240885    0.348958
# std      6.875374                  0.331329   11.760232    0.476951
# min     18.200000                  0.078000   21.000000    0.000000
# 25%     27.500000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.127964       0.208984       0.013376
# Glucose                      0.127964  1.000000       0.219666       0.160766
# BloodPressure                0.208984  0.219666       1.000000       0.134155
# SkinThickness                0.013376  0.160766       0.134155       1.000000
# Insulin                     -0.018082  0.396597       0.010926       0.240361
# BMI                          0.021546  0.231478       0.281231       0.535703
# DiabetesPedigreeFunction    -0.033523  0.137106       0.000371       0.154961
# Age                          0.544341  0.266600       0.326740       0.026423
# Outcome                      0.221898  0.492908       0.162986       0.175026
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.018082  0.021546                 -0.033523
# Glucose                   0.396597  0.231478                  0.137106
# BloodPressure             0.010926  0.281231                  0.000371
# SkinThickness             0.240361  0.535703                  0.154961
# Insulin                   1.000000  0.189856                  0.157806
# BMI                       0.189856  1.000000                  0.153508
# DiabetesPedigreeFunction  0.157806  0.153508                  1.000000
# Age                       0.038652  0.025748                  0.033561
# Outcome                   0.179185  0.312254                  0.173844
#
#                                Age   Outcome
# Pregnancies               0.544341  0.221898
# Glucose                   0.266600  0.492908
# BloodPressure             0.326740  0.162986
# SkinThickness             0.026423  0.175026
# Insulin                   0.038652  0.179185
# BMI                       0.025748  0.312254
# DiabetesPedigreeFunction  0.033561  0.173844
# Age                       1.000000  0.238356
# Outcome                   0.238356  1.000000

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot: >

# %%
plt.figure(figsize=(15,10))
sns.boxplot(df)
# Out:
# <AxesSubplot: >

# %%
X=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6    148.0           72.0      35.000000   79.799479  33.6
# 1              1     85.0           66.0      29.000000   79.799479  26.6
# 2              8    183.0           64.0      20.536458   79.799479  23.3
# 3              1     89.0           66.0      23.000000   94.000000  28.1
# 4              0    137.0           40.0      35.000000  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763           10    101.0           76.0      48.000000  180.000000  32.9
# 764            2    122.0           70.0      27.000000   79.799479  36.8
# 765            5    121.0           72.0      23.000000  112.000000  26.2
# 766            1    126.0           60.0      20.536458   79.799479  30.1
# 767            1     93.0           70.0      31.000000   79.799479  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# 764                     0.340   27
# 765                     0.245   30
# 766                     0.349   47
# 767                     0.315   23
#
# [768 rows x 8 columns]

# %%
y.value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=12)
X_train.shape, X_test.shape
# Out:
# ((576, 8), (192, 8))

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
treeclassifier=DecisionTreeClassifier()

# %%
treeclassifier.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter={
 'criterion':['gini','entropy','log_loss'],
  'splitter':['best','random'],
  'max_depth':[1,2,3,4,5],
  'max_features':['auto', 'sqrt', 'log2']
    
}

# %%
clf=GridSearchCV(treeclassifier,param_grid=parameter,cv=7,scoring='accuracy')

# %%
clf.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=7, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [1, 2, 3, 4, 5],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              scoring='accuracy')

# %%
clf.best_params_
# Out:
# {'criterion': 'log_loss',
#  'max_depth': 5,
#  'max_features': 'auto',
#  'splitter': 'best'}

# %%
clf.best_score_
# Out:
# 0.7586583266865371

# %%
y_pred=clf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix , accuracy_score , classification_report

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[114,   7],
#        [ 60,  11]])

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.6510416666666666

# %%
classification_report(y_test,y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.66      0.94      0.77       121\n           1       0.61      0.15      0.25        71\n\n    accuracy                           0.65       192\n   macro avg       0.63      0.55      0.51       192\nweighted avg       0.64      0.65      0.58       192\n'

# %%
from sklearn import tree
plt.figure(figsize=(20,10))
tree.plot_tree(treeclassifier,filled=True)
# Out:
# [Text(0.4761284722222222, 0.96875, 'x[1] <= 127.5\ngini = 0.45\nsamples = 576\nvalue = [379, 197]'),
#  Text(0.2532986111111111, 0.90625, 'x[7] <= 29.5\ngini = 0.301\nsamples = 369\nvalue = [301, 68]'),
#  Text(0.14270833333333333, 0.84375, 'x[5] <= 45.4\ngini = 0.158\nsamples = 220\nvalue = [201, 19]'),
#  Text(0.13159722222222223, 0.78125, 'x[0] <= 6.5\ngini = 0.129\nsamples = 216\nvalue = [201, 15]'),
#  Text(0.08402777777777778, 0.71875, 'x[5] <= 32.25\ngini = 0.115\nsamples = 212\nvalue = [199, 13]'),
#  Text(0.022222222222222223, 0.65625, 'x[6] <= 0.668\ngini = 0.016\nsamples = 128\nvalue = [127, 1]'),
#  Text(0.011111111111111112, 0.59375, 'gini = 0.0\nsamples = 112\nvalue = [112, 0]'),
#  Text(0.03333333333333333, 0.59375, 'x[5] <= 23.55\ngini = 0.117\nsamples = 16\nvalue = [15, 1]'),
#  Text(0.022222222222222223, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.044444444444444446, 0.53125, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.14583333333333334, 0.65625, 'x[6] <= 0.69\ngini = 0.245\nsamples = 84\nvalue = [72, 12]'),
#  Text(0.07777777777777778, 0.59375, 'x[5] <= 32.55\ngini = 0.178\nsamples = 71\nvalue = [64, 7]'),
#  Text(0.06666666666666667, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.08888888888888889, 0.53125, 'x[6] <= 0.135\ngini = 0.134\nsamples = 69\nvalue = [64, 5]'),
#  Text(0.058333333333333334, 0.46875, 'x[2] <= 65.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.04722222222222222, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.06944444444444445, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11944444444444445, 0.46875, 'x[4] <= 38.0\ngini = 0.112\nsamples = 67\nvalue = [63, 4]'),
#  Text(0.09166666666666666, 0.40625, 'x[3] <= 27.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.08055555555555556, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.10277777777777777, 0.34375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.14722222222222223, 0.40625, 'x[6] <= 0.501\ngini = 0.089\nsamples = 64\nvalue = [61, 3]'),
#  Text(0.125, 0.34375, 'x[3] <= 20.768\ngini = 0.04\nsamples = 49\nvalue = [48, 1]'),
#  Text(0.11388888888888889, 0.28125, 'x[5] <= 34.15\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.10277777777777777, 0.21875, 'x[7] <= 24.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.09166666666666666, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11388888888888889, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.125, 0.21875, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.1361111111111111, 0.28125, 'gini = 0.0\nsamples = 43\nvalue = [43, 0]'),
#  Text(0.16944444444444445, 0.34375, 'x[6] <= 0.505\ngini = 0.231\nsamples = 15\nvalue = [13, 2]'),
#  Text(0.15833333333333333, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.18055555555555555, 0.28125, 'x[4] <= 157.5\ngini = 0.133\nsamples = 14\nvalue = [13, 1]'),
#  Text(0.16944444444444445, 0.21875, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.19166666666666668, 0.21875, 'x[6] <= 0.601\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.18055555555555555, 0.15625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.20277777777777778, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.21388888888888888, 0.59375, 'x[2] <= 77.0\ngini = 0.473\nsamples = 13\nvalue = [8, 5]'),
#  Text(0.20277777777777778, 0.53125, 'x[2] <= 64.5\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(0.19166666666666668, 0.46875, 'x[7] <= 24.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.18055555555555555, 0.40625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.20277777777777778, 0.40625, 'x[5] <= 35.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.19166666666666668, 0.34375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.21388888888888888, 0.34375, 'x[6] <= 0.787\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.20277777777777778, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.225, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.21388888888888888, 0.46875, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.225, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.17916666666666667, 0.71875, 'x[5] <= 30.196\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.16805555555555557, 0.65625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.19027777777777777, 0.65625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.15381944444444445, 0.78125, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.3638888888888889, 0.84375, 'x[5] <= 26.8\ngini = 0.441\nsamples = 149\nvalue = [100, 49]'),
#  Text(0.3527777777777778, 0.78125, 'gini = 0.0\nsamples = 28\nvalue = [28, 0]'),
#  Text(0.375, 0.78125, 'x[1] <= 89.5\ngini = 0.482\nsamples = 121\nvalue = [72, 49]'),
#  Text(0.3638888888888889, 0.71875, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]'),
#  Text(0.3861111111111111, 0.71875, 'x[3] <= 32.5\ngini = 0.5\nsamples = 100\nvalue = [51, 49]'),
#  Text(0.32222222222222224, 0.65625, 'x[2] <= 85.5\ngini = 0.489\nsamples = 75\nvalue = [32, 43]'),
#  Text(0.3, 0.59375, 'x[6] <= 0.132\ngini = 0.458\nsamples = 62\nvalue = [22, 40]'),
#  Text(0.28888888888888886, 0.53125, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.3111111111111111, 0.53125, 'x[4] <= 79.4\ngini = 0.428\nsamples = 58\nvalue = [18, 40]'),
#  Text(0.3, 0.46875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.32222222222222224, 0.46875, 'x[7] <= 57.0\ngini = 0.408\nsamples = 56\nvalue = [16, 40]'),
#  Text(0.3111111111111111, 0.40625, 'x[0] <= 6.5\ngini = 0.384\nsamples = 54\nvalue = [14, 40]'),
#  Text(0.25833333333333336, 0.34375, 'x[2] <= 65.0\ngini = 0.458\nsamples = 31\nvalue = [11, 20]'),
#  Text(0.24722222222222223, 0.28125, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.26944444444444443, 0.28125, 'x[7] <= 34.5\ngini = 0.483\nsamples = 27\nvalue = [11, 16]'),
#  Text(0.24166666666666667, 0.21875, 'x[0] <= 2.5\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.23055555555555557, 0.15625, 'x[1] <= 111.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.21944444444444444, 0.09375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.24166666666666667, 0.09375, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.25277777777777777, 0.15625, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.2972222222222222, 0.21875, 'x[3] <= 29.5\ngini = 0.401\nsamples = 18\nvalue = [5, 13]'),
#  Text(0.2861111111111111, 0.15625, 'x[2] <= 69.553\ngini = 0.305\nsamples = 16\nvalue = [3, 13]'),
#  Text(0.2638888888888889, 0.09375, 'x[0] <= 3.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.25277777777777777, 0.03125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.275, 0.03125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.30833333333333335, 0.09375, 'x[6] <= 0.167\ngini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(0.2972222222222222, 0.03125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3194444444444444, 0.03125, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.30833333333333335, 0.15625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3638888888888889, 0.34375, 'x[1] <= 121.0\ngini = 0.227\nsamples = 23\nvalue = [3, 20]'),
#  Text(0.33055555555555555, 0.28125, 'x[2] <= 83.0\ngini = 0.105\nsamples = 18\nvalue = [1, 17]'),
#  Text(0.3194444444444444, 0.21875, 'gini = 0.0\nsamples = 16\nvalue = [0, 16]'),
#  Text(0.3416666666666667, 0.21875, 'x[3] <= 26.268\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.33055555555555555, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3527777777777778, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3972222222222222, 0.28125, 'x[6] <= 0.6\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.3861111111111111, 0.21875, 'x[6] <= 0.231\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.375, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3972222222222222, 0.15625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.4083333333333333, 0.21875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3333333333333333, 0.40625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.34444444444444444, 0.59375, 'x[6] <= 0.37\ngini = 0.355\nsamples = 13\nvalue = [10, 3]'),
#  Text(0.3333333333333333, 0.53125, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.35555555555555557, 0.53125, 'x[1] <= 108.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.34444444444444444, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.36666666666666664, 0.46875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.45, 0.65625, 'x[4] <= 203.5\ngini = 0.365\nsamples = 25\nvalue = [19, 6]'),
#  Text(0.4222222222222222, 0.59375, 'x[2] <= 94.0\ngini = 0.188\nsamples = 19\nvalue = [17, 2]'),
#  Text(0.4, 0.53125, 'x[2] <= 62.0\ngini = 0.111\nsamples = 17\nvalue = [16, 1]'),
#  Text(0.3888888888888889, 0.46875, 'x[2] <= 59.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.37777777777777777, 0.40625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.4, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4111111111111111, 0.46875, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.4444444444444444, 0.53125, 'x[4] <= 75.9\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.43333333333333335, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.45555555555555555, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4777777777777778, 0.59375, 'x[5] <= 36.25\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.4666666666666667, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.4888888888888889, 0.53125, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.6989583333333333, 0.90625, 'x[5] <= 29.95\ngini = 0.47\nsamples = 207\nvalue = [78, 129]'),
#  Text(0.5611111111111111, 0.84375, 'x[1] <= 145.5\ngini = 0.456\nsamples = 54\nvalue = [35, 19]'),
#  Text(0.5333333333333333, 0.78125, 'x[3] <= 34.0\ngini = 0.312\nsamples = 31\nvalue = [25, 6]'),
#  Text(0.5222222222222223, 0.71875, 'x[0] <= 4.5\ngini = 0.278\nsamples = 30\nvalue = [25, 5]'),
#  Text(0.5111111111111111, 0.65625, 'x[0] <= 1.5\ngini = 0.375\nsamples = 20\nvalue = [15, 5]'),
#  Text(0.5, 0.59375, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.5222222222222223, 0.59375, 'x[5] <= 23.45\ngini = 0.496\nsamples = 11\nvalue = [6, 5]'),
#  Text(0.5111111111111111, 0.53125, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.5333333333333333, 0.53125, 'x[1] <= 140.0\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.5222222222222223, 0.46875, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.5444444444444444, 0.46875, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.5333333333333333, 0.65625, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.5444444444444444, 0.71875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5888888888888889, 0.78125, 'x[2] <= 74.5\ngini = 0.491\nsamples = 23\nvalue = [10, 13]'),
#  Text(0.5666666666666667, 0.71875, 'x[2] <= 60.0\ngini = 0.375\nsamples = 12\nvalue = [3, 9]'),
#  Text(0.5555555555555556, 0.65625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5777777777777777, 0.65625, 'x[6] <= 0.209\ngini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(0.5666666666666667, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5888888888888889, 0.59375, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.6111111111111112, 0.71875, 'x[7] <= 40.0\ngini = 0.463\nsamples = 11\nvalue = [7, 4]'),
#  Text(0.6, 0.65625, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.6222222222222222, 0.65625, 'x[1] <= 159.0\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.6111111111111112, 0.59375, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6333333333333333, 0.59375, 'x[6] <= 0.155\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.6222222222222222, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6444444444444445, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8368055555555556, 0.84375, 'x[6] <= 0.309\ngini = 0.404\nsamples = 153\nvalue = [43, 110]'),
#  Text(0.7333333333333333, 0.78125, 'x[1] <= 154.5\ngini = 0.499\nsamples = 48\nvalue = [23, 25]'),
#  Text(0.7111111111111111, 0.71875, 'x[4] <= 301.0\ngini = 0.435\nsamples = 25\nvalue = [17, 8]'),
#  Text(0.7, 0.65625, 'x[7] <= 67.5\ngini = 0.386\nsamples = 23\nvalue = [17, 6]'),
#  Text(0.6888888888888889, 0.59375, 'x[2] <= 91.0\ngini = 0.351\nsamples = 22\nvalue = [17, 5]'),
#  Text(0.6666666666666666, 0.53125, 'x[3] <= 39.5\ngini = 0.266\nsamples = 19\nvalue = [16, 3]'),
#  Text(0.6555555555555556, 0.46875, 'x[6] <= 0.257\ngini = 0.198\nsamples = 18\nvalue = [16, 2]'),
#  Text(0.6444444444444445, 0.40625, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.6666666666666666, 0.40625, 'x[7] <= 23.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.6555555555555556, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6777777777777778, 0.34375, 'x[6] <= 0.259\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.6666666666666666, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6888888888888889, 0.28125, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.6777777777777778, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7111111111111111, 0.53125, 'x[7] <= 31.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.7, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7222222222222222, 0.46875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7111111111111111, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7222222222222222, 0.65625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7555555555555555, 0.71875, 'x[3] <= 16.5\ngini = 0.386\nsamples = 23\nvalue = [6, 17]'),
#  Text(0.7444444444444445, 0.65625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7666666666666667, 0.65625, 'x[3] <= 34.0\ngini = 0.308\nsamples = 21\nvalue = [4, 17]'),
#  Text(0.7444444444444445, 0.59375, 'x[1] <= 177.0\ngini = 0.208\nsamples = 17\nvalue = [2, 15]'),
#  Text(0.7333333333333333, 0.53125, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.7555555555555555, 0.53125, 'x[0] <= 6.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.7444444444444445, 0.46875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.7666666666666667, 0.46875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7888888888888889, 0.59375, 'x[1] <= 173.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.7777777777777778, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9402777777777778, 0.78125, 'x[1] <= 165.5\ngini = 0.308\nsamples = 105\nvalue = [20, 85]'),
#  Text(0.9138888888888889, 0.71875, 'x[1] <= 163.5\ngini = 0.392\nsamples = 71\nvalue = [19, 52]'),
#  Text(0.9027777777777778, 0.65625, 'x[4] <= 282.0\ngini = 0.36\nsamples = 68\nvalue = [16, 52]'),
#  Text(0.8611111111111112, 0.59375, 'x[2] <= 73.0\ngini = 0.316\nsamples = 61\nvalue = [12, 49]'),
#  Text(0.8222222222222222, 0.53125, 'x[1] <= 149.5\ngini = 0.087\nsamples = 22\nvalue = [1, 21]'),
#  Text(0.8111111111111111, 0.46875, 'gini = 0.0\nsamples = 16\nvalue = [0, 16]'),
#  Text(0.8333333333333334, 0.46875, 'x[7] <= 30.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.8222222222222222, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8444444444444444, 0.40625, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.9, 0.53125, 'x[4] <= 142.0\ngini = 0.405\nsamples = 39\nvalue = [11, 28]'),
#  Text(0.8777777777777778, 0.46875, 'x[0] <= 10.0\ngini = 0.473\nsamples = 26\nvalue = [10, 16]'),
#  Text(0.8666666666666667, 0.40625, 'x[5] <= 47.7\ngini = 0.444\nsamples = 24\nvalue = [8, 16]'),
#  Text(0.8555555555555555, 0.34375, 'x[5] <= 39.65\ngini = 0.48\nsamples = 20\nvalue = [8, 12]'),
#  Text(0.8333333333333334, 0.28125, 'x[6] <= 0.398\ngini = 0.337\nsamples = 14\nvalue = [3, 11]'),
#  Text(0.8222222222222222, 0.21875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8444444444444444, 0.21875, 'x[7] <= 68.0\ngini = 0.153\nsamples = 12\nvalue = [1, 11]'),
#  Text(0.8333333333333334, 0.15625, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.8555555555555555, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8777777777777778, 0.28125, 'x[7] <= 23.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.8666666666666667, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8888888888888888, 0.21875, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.8777777777777778, 0.34375, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.8888888888888888, 0.40625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9222222222222223, 0.46875, 'x[7] <= 26.5\ngini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(0.9111111111111111, 0.40625, 'x[4] <= 182.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.9, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9222222222222223, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9333333333333333, 0.40625, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.9444444444444444, 0.59375, 'x[7] <= 32.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.9333333333333333, 0.53125, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.9555555555555556, 0.53125, 'x[6] <= 0.63\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.9444444444444444, 0.46875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.9666666666666667, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.925, 0.65625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.9666666666666667, 0.71875, 'x[5] <= 46.1\ngini = 0.057\nsamples = 34\nvalue = [1, 33]'),
#  Text(0.9555555555555556, 0.65625, 'gini = 0.0\nsamples = 32\nvalue = [0, 32]'),
#  Text(0.9777777777777777, 0.65625, 'x[3] <= 47.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.9666666666666667, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9888888888888889, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]')]
